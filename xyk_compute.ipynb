# %%
# import numpy as np
# import pandas as pd
# import sys
# import time
# import datetime
# import pickle

def sxf_compute(num):
    if num<=300:
        cost = 0.0038*num
    else:
        cost = 0.006*num + 2
    return num-cost    


def small_test(num=1900000):
    for i in range(10):
        if 3+4>9:
            num = 10
        else: 
            num = 21
    
    return num

def fff1():
    global global_v
    global_v['a'] = 100

def fff2():
    global global_v
    global_v['b'] = 100
    print('global_v is ', global_v)
    
class Test:
    def func(self):
        if not hasattr(self, "ttt_n"):
            self.ttt_n = -1
        else:
            self.ttt_n += 1
        return self.ttt_n    

def getTrainBatch():
    labels = []
    print('hello world222')
    print(batchSize)
    arr = np.zeros([batchSize, maxSeqLength])
    for i in range(batchSize):
        if (i % 2 == 0): 
            num = randint(1,11499)
            labels.append([1,0])
        else:
            num = randint(13499,24999)
            labels.append([0,1])
        arr[i] = ids[num-1:num]
    return arr, labels

def getTestBatch():
    labels = []
    arr = np.zeros([batchSize, maxSeqLength])
    for i in range(batchSize):
        num = randint(11499,13499)
        if (num <= 12499):
            labels.append([1,0])
        else:
            labels.append([0,1])
        arr[i] = ids[num-1:num]
    return arr, labels

def lakala_compute(num):
    cost = 0.0058*num + 2
    return num-cost

def xgd_compute(num):
    cost = 0.006*num
    return num-cost

def qianbao_compute(num):
    cost = 0.0055*num
#    cost = 0.0038*num
    return num-cost

num1 = qianbao_compute(256*4)
print('qianbao_compute outcome is ', num1)

# num2 = xgd_compute(386)
# print('xgd_compute outcome is num2 ', num2)

print('hello world')
# Out:
# qianbao_compute outcome is  1018.368
# hello world
